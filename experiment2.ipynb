# %%
c= float (input("Enter the temperature in Celsius:"))
f= (c*9/5)+32
print("The corresponding Fahrenheit:",f)
# Out:
# Enter the temperature in Celsius: 34
# The corresponding Fahrenheit: 93.2

# %%
km = float(input("Enter the distance in kilometer:"))
m= km*0.62137
print(f"The corresponding miles: {m:.2f}")
# Out:
# Enter the distance in kilometer: 2
# The corresponding miles: 1.24
