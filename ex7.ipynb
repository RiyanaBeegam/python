# %%
#colors in set1 but not in set2.
clr1=set(input("Enter colors:").split(','))
clr2=set(input("Enter colors:").split(','))
diff=clr1-clr2
print("The first color set is: ",clr1)
print("The second color set is: ",clr2)
print("color set is:",diff)
# Out:
# Enter colors: blue,red,purple,green
# Enter colors: purple,pink,violet,red
# The first color set is:  {'green', 'blue', 'purple', 'red'}
# The second color set is:  {'pink', 'violet', 'purple', 'red'}
# color set is: {'green', 'blue'}

# %%
#to printout all colors from colorset1 and colorset2
clr1=set(input("Enter colors:").split(','))
clr2=set(input("Enter colors:").split(','))
colors=clr1 | clr2
print("The first color set is: ",clr1)
print("The second color set is: ",clr2)
print("color set is:",colors)
# Out:
# Enter colors: red,pink,violet,purple
# Enter colors: black,blue,green,white
# The first color set is:  {'pink', 'violet', 'purple', 'red'}
# The second color set is:  {'black', 'blue', 'green', 'white'}
# color set is: {'blue', 'violet', 'purple', 'red', 'white', 'pink', 'green', 'black'}
